# %% [markdown]
# ## Importing and Cleaning Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("spam.csv")

# %%
df.isna().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5158
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                   Unnamed: 3 Unnamed: 4
# count                     12          6
# unique                    10          5
# top     MK17 92H. 450Ppw 16"    GNT:-)"
# freq                       2          2

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.describe()
# Out:
#           v1                      v2
# count   5572                    5572
# unique     2                    5158
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
df.rename(columns={"v1":"target","v2":"text"}, inplace=True)

# %%
df.describe()
# Out:
#        target                    text
# count    5572                    5572
# unique      2                    5158
# top       ham  Sorry, I'll call later
# freq     4825                      30

# %%
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['target']=le.fit_transform(df['target'])

# 0 for HAM and 1 for SPAM

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 414

# %%
df.drop_duplicates(keep="first", inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5158, 2)

# %% [markdown]
# ## EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     642
# Name: count, dtype: int64

# %%
df['target'].hist()
#Data is imbalanced
# Out:
# <Axes: >

# %%
plt.pie(df['target'].value_counts(), labels=['ham', 'spam'], autopct="%0.1f")
# Out:
# ([<matplotlib.patches.Wedge at 0x13feb9890>,
#   <matplotlib.patches.Wedge at 0x14c0278d0>],
#  [Text(-1.016971146764745, 0.41924895545248453, 'ham'),
#   Text(1.016971156577975, -0.4192489316485567, 'spam')],
#  [Text(-0.5547115345989518, 0.2286812484286279, '87.6'),
#   Text(0.5547115399516227, -0.22868123544466726, '12.4')])

# %%
import nltk
# import ssl

# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context

# nltk.download("punkt")
# nltk.download('stopwords')

# %%
df['text_char'] = df['text'].apply(len)

# %%
df.sample(10)
# Out:
#       target                                               text  text_char
# 2003       0  S....s...india going to draw the series after ...         80
# 918        0  Hey you gave them your photo when you register...         88
# 2834       0  Ya they are well and fine., BBD(pooja) full pi...        131
# 589        0                 I'm in a meeting, call me later at         34
# 1869       0                     Mom wants to know where you at         30
# 3706       0               Aight do you still want to get money         36
# 3628       0               Should I head straight there or what         36
# 3013       0     I might go 2 sch. Yar at e salon now v boring.         46
# 2357       0  Okay same with me. Well thanks for the clarifi...         52
# 5503       0  Perhaps * is much easy give your account ident...         82

# %%
df['text_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df['text_sent'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df.sample(10)
# Out:
#       target                                               text  text_char  \
# 4291       0                                              G.W.R          5
# 4078       0     O i played smash bros  &lt;#&gt;  religiously.         46
# 1626       0                          Dear how you. Are you ok?         25
# 3724       0                 Nothing spl..wat abt u and whr ru?         34
# 4276       0           I'm glad. You are following your dreams.         40
# 5557       0  No. I meant the calculation is the same. That ...        273
# 2574       1  Your next amazing xxx PICSFREE1 video will be ...        153
# 4392       1  RECPT 1/3. You have ordered a Ringtone. Your o...         72
# 377        0  Well there's not a lot of things happening in ...        131
# 1967       0  Even i cant close my eyes you are in me our va...         65
#
#       text_words  text_sent
# 4291           1          1
# 4078          14          1
# 1626           8          2
# 3724          10          1
# 4276          10          2
# 5557          67          7
# 2574          32          2
# 4392          15          3
# 377           28          1
# 1967          16          1

# %%
df.describe()
# Out:
#             target    text_char   text_words    text_sent
# count  5158.000000  5158.000000  5158.000000  5158.000000
# mean      0.124467    78.806708    18.430399     1.962195
# std       0.330145    58.187284    13.326907     1.445515
# min       0.000000     2.000000     1.000000     1.000000
# 25%       0.000000    36.000000     9.000000     1.000000
# 50%       0.000000    60.000000    15.000000     1.000000
# 75%       0.000000   116.000000    26.000000     2.000000
# max       1.000000   910.000000   220.000000    38.000000

# %%
df_ham = df[df['target']==0]
df_spam = df[df['target']==1]

# %%
df_ham.describe()
# Out:
#        target    text_char   text_words    text_sent
# count  4516.0  4516.000000  4516.000000  4516.000000
# mean      0.0    70.449734    17.123782     1.820195
# std       0.0    56.352902    13.493970     1.383657
# min       0.0     2.000000     1.000000     1.000000
# 25%       0.0    34.000000     8.000000     1.000000
# 50%       0.0    52.000000    13.000000     1.000000
# 75%       0.0    90.000000    22.000000     2.000000
# max       0.0   910.000000   220.000000    38.000000

# %%
df_spam.describe()
# Out:
#        target  text_char  text_words   text_sent
# count   642.0  642.00000  642.000000  642.000000
# mean      1.0  137.59190   27.621495    2.961059
# std       0.0   30.29638    7.048863    1.477880
# min       1.0   13.00000    2.000000    1.000000
# 25%       1.0  131.25000   25.000000    2.000000
# 50%       1.0  148.00000   29.000000    3.000000
# 75%       1.0  157.00000   32.000000    4.000000
# max       1.0  224.00000   46.000000    9.000000

# %%
sns.histplot(df_ham['text_char'])
sns.histplot(df_spam['text_char'], color='red')
# Out:
# <Axes: xlabel='text_char', ylabel='Count'>

# %%
sns.histplot(df_ham['text_words'])
sns.histplot(df_spam['text_words'], color='red')
# Out:
# <Axes: xlabel='text_words', ylabel='Count'>

# %%
sns.histplot(df_ham['text_sent'])
sns.histplot(df_spam['text_sent'], color='red')
# Out:
# <Axes: xlabel='text_sent', ylabel='Count'>

# %%
#In general there spam messages contain more words and characters

# %%
sns.pairplot(df, hue="target")

# %%
df.drop('text', axis=1).corr()['target'].sort_values(ascending=False)
# Out:
# target        1.000000
# text_char     0.380954
# text_sent     0.260565
# text_words    0.260058
# Name: target, dtype: float64

# %%
sns.heatmap(df.drop('text', axis=1).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Preprocessing

# %%
import string
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

ps = PorterStemmer()

def process_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)

    final = []
    for t in text:
        if t.isalnum():
            final.append(t)

    text = final[:] #Copy by value
    final.clear()

    for t in text:
        if t not in stopwords.words("english") and t not in string.punctuation:
            final.append(t)

    text = final[:]
    final.clear()

    for t in text:
        final.append(ps.stem(t))

    return " ".join(final)

# %%
df['processed_text'] = df['text'].apply(process_text)

# %%
df.sample(10)
# Out:
#       target                                               text  text_char  \
# 916        0  Was actually about to send you a reminder toda...         73
# 5398       0  Hi. Hope you had a good day. Have a better night.         49
# 4638       0  Of course. I guess god's just got me on hold r...         55
# 855        1  Talk sexy!! Make new friends or fall in love i...        144
# 3138       0                                Is ur lecture over?         19
# 3081       0  And very importantly, all we discuss is betwee...         61
# 409        0  Message:some text missing* Sender:Name Missing...        152
# 694        0  Ah poop. Looks like ill prob have to send in m...         92
# 4407       0  Take care and sleep well.you need to learn to ...        283
# 2682       0  I got a call from a landline number. . . I am ...        106
#
#       text_words  text_sent                                     processed_text
# 916           14          2            actual send remind today wonder weekend
# 5398          14          3                      hi hope good day better night
# 4638          15          2                     cours guess god got hold right
# 855           32          3  talk sexi make new friend fall love world disc...
# 3138           5          1                                          ur lectur
# 3081          14          1                              importantli discuss u
# 409           32          1  messag text miss sender name miss number miss ...
# 694           22          2  ah poop look like ill prob send laptop get fix...
# 4407          51          1  take care sleep need learn chang need get conv...
# 2682          28          7  got call landlin number ask come anna nagar go...

# %%
df_ham = df[df['target']==0]
df_spam = df[df['target']==1]

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(width=700, height=700, min_font_size=5, background_color="white")
wc_ham=wc.generate(df_ham['processed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,8))
plt.imshow(wc_ham)

# %%
wc = WordCloud(width=700, height=700, min_font_size=5, background_color="white")
wc_spam=wc.generate(df_spam['processed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,8))
plt.imshow(wc_spam)

# %% [markdown]
# ## Test Train Split

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()

X = cv.fit_transform(df['processed_text']).toarray()
y = df['target']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedShuffleSplit

#Since the data is imbalanced, we cannot have a direct split
split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
for train_index, test_index in split.split(X, y):
    strat_train_set = X[train_index], y.iloc[train_index]
    strat_test_set = X[test_index], y.iloc[test_index]

X_train, y_train = strat_train_set
X_test, y_test = strat_test_set

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
svc = SVC(kernel="sigmoid", gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver="liblinear", penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=101)
abc = AdaBoostClassifier(n_estimators=50, random_state=101)
bc = BaggingClassifier(n_estimators=50, random_state=101)
etc = ExtraTreesClassifier(n_estimators=50, random_state=101)
gbc = GradientBoostingClassifier(n_estimators=50, random_state=101)

# %%
models = {
    'svc' : svc,
    'knc' : knc,
    'mnb' : mnb,
    'dtc' : dtc,
    'lrc' : lrc,
    'rfc' : rfc,
    'abc' : abc,
    'bc'  : bc,
    'etc' : etc,
    'gbc' : gbc
}

# %%
from sklearn.metrics import accuracy_score, precision_score

def train_model(model, model_name):
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)

    print("----------> Model Trained: ", model_name)
    return accuracy, precision

# %%
accuracy_scores = []
precision_scores = []

for name, model in models.items():
    model_accuracy, model_precision = train_model(model, name)
    accuracy_scores.append(model_accuracy)
    precision_scores.append(model_precision)
# Out:
# ----------> Model Trained:  svc
# ----------> Model Trained:  knc
# ----------> Model Trained:  mnb
# ----------> Model Trained:  dtc
# ----------> Model Trained:  lrc
# ----------> Model Trained:  rfc
# ----------> Model Trained:  abc
# ----------> Model Trained:  bc
# ----------> Model Trained:  etc
# ----------> Model Trained:  gbc

# %%
performance_df = pd.DataFrame({'Algorithm':models.keys(), 'Accuracy':accuracy_scores, 'Precision':precision_scores})

# %%
#Here Precision Matters more as the data is imbalanced
performance_df.sort_values('Precision', ascending=False, )
# Out:
#   Algorithm  Accuracy  Precision
# 5       rfc  0.967700   0.993103
# 9       gbc  0.951550   0.983607
# 1       knc  0.912145   0.983051
# 4       lrc  0.977390   0.964706
# 7        bc  0.967054   0.961039
# 8       etc  0.970930   0.956790
# 3       dtc  0.934755   0.925926
# 2       mnb  0.978036   0.911917
# 6       abc  0.962532   0.904192
# 0       svc  0.930233   0.732240

# %%
#The Best Models from here are RFC and ETC

# %% [markdown]
# ## Model Tuning

# %%
rfc = RandomForestClassifier
etc = ExtraTreesClassifier
knc = KNeighborsClassifier

# %%
from sklearn.model_selection import GridSearchCV

models = {
    'rfc' : rfc,
    'etc' : etc,
    'knc' : knc
}

param_grid = {
    'rfc': {
        'n_estimators': [100, 200],
        'max_depth': [20, 30, 50],
        'min_samples_split': [2, 5, 10],
    },
    'etc': {
        'n_estimators': [100, 200],
        'max_depth': [20, 30, 50],
        'min_samples_split': [2, 5, 10],
    },
    'knc': {
        'n_neighbors': [2, 3],
        'weights': ['distance'],
        'metric': ['euclidean', 'manhattan'],
    },
}

def get_params_string(params):
    params_arr = []
    for key, value in params.items():
        param_string = key + " : " + str(value)
        params_arr.append(param_string)
    return ", ".join(params_arr)

def tune_model(model, model_name):
    grid=GridSearchCV(model(), param_grid[model_name], cv=5, verbose=3)
    grid.fit(X_train, y_train)

    model = grid.best_estimator_
    models[model_name] = model
    
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)

    print("----------> Model Trained: ", model_name)
    
    return accuracy, precision, get_params_string(grid.best_params_)

# %%
accuracy_scores = []
precision_scores = []
params = []

for name, model in models.items():
    model_accuracy, model_precision, model_params = tune_model(model, name)
    accuracy_scores.append(model_accuracy)
    precision_scores.append(model_precision)
    params.append(model_params)

performance_df = pd.DataFrame({'Algorithm':models.keys(), 'Accuracy':accuracy_scores, 'Precision':precision_scores, 'Params': params})
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.934 total time=   1.1s
# [CV 2/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.928 total time=   1.0s
# [CV 3/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.925 total time=   1.0s
# [CV 4/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.932 total time=   1.0s
# [CV 5/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.928 total time=   1.0s
# [CV 1/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.934 total time=   2.0s
# [CV 2/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.935 total time=   2.0s
# [CV 3/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.925 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.934 total time=   1.9s
# [CV 5/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.925 total time=   1.9s
# [CV 1/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.939 total time=   1.0s
# [CV 2/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.934 total time=   1.1s
# [CV 3/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.927 total time=   1.2s
# [CV 4/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.935 total time=   1.1s
# [CV 5/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.924 total time=   1.1s
# [CV 1/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.935 total time=   2.0s
# [CV 2/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.935 total time=   2.0s
# [CV 3/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.928 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.934 total time=   1.9s
# [CV 5/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.929 total time=   1.9s
# [CV 1/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.936 total time=   1.0s
# [CV 2/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.929 total time=   1.0s
# [CV 3/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.927 total time=   1.0s
# [CV 4/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.936 total time=   1.0s
# [CV 5/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.932 total time=   1.0s
# [CV 1/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.935 total time=   1.9s
# [CV 2/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.934 total time=   1.9s
# [CV 3/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.925 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.932 total time=   2.1s
# [CV 5/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.924 total time=   2.1s
# [CV 1/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.950 total time=   1.5s
# [CV 2/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.946 total time=   1.5s
# [CV 3/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.940 total time=   1.5s
# [CV 4/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.950 total time=   1.4s
# [CV 5/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.939 total time=   1.5s
# [CV 1/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.950 total time=   2.9s
# [CV 2/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.945 total time=   2.9s
# [CV 3/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.940 total time=   2.8s
# [CV 4/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.952 total time=   2.7s
# [CV 5/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.939 total time=   2.7s
# [CV 1/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.953 total time=   1.3s
# [CV 2/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.950 total time=   1.3s
# [CV 3/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.949 total time=   1.3s
# [CV 4/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.953 total time=   1.4s
# [CV 5/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.940 total time=   1.3s
# [CV 1/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.953 total time=   2.6s
# [CV 2/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.952 total time=   2.6s
# [CV 3/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.938 total time=   2.7s
# [CV 4/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.950 total time=   2.6s
# [CV 5/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.945 total time=   2.6s
# [CV 1/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.952 total time=   1.3s
# [CV 2/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.947 total time=   1.3s
# [CV 3/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.950 total time=   1.3s
# [CV 4/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.956 total time=   1.3s
# [CV 5/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.940 total time=   1.3s
# [CV 1/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.952 total time=   2.5s
# [CV 2/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.953 total time=   2.5s
# [CV 3/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.942 total time=   2.6s
# [CV 4/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.954 total time=   2.6s
# [CV 5/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.940 total time=   2.5s
# [CV 1/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.960 total time=   1.9s
# [CV 2/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.956 total time=   1.9s
# [CV 3/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.965 total time=   1.9s
# [CV 4/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.963 total time=   1.9s
# [CV 5/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.947 total time=   1.9s
# [CV 1/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.960 total time=   3.8s
# [CV 2/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.964 total time=   3.8s
# [CV 3/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.958 total time=   3.8s
# [CV 4/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.963 total time=   3.8s
# [CV 5/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.947 total time=   3.8s
# [CV 1/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.964 total time=   1.9s
# [CV 2/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.967 total time=   1.9s
# [CV 3/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.960 total time=   1.9s
# [CV 4/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.964 total time=   1.9s
# [CV 5/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.949 total time=   1.9s
# [CV 1/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.960 total time=   3.7s
# [CV 2/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.964 total time=   3.7s
# [CV 3/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.967 total time=   3.7s
# [CV 4/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.967 total time=   3.7s
# [CV 5/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.952 total time=   3.7s
# [CV 1/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.964 total time=   1.9s
# [CV 2/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.964 total time=   1.8s
# [CV 3/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.961 total time=   1.9s
# [CV 4/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.967 total time=   1.9s
# [CV 5/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.953 total time=   1.9s
# [CV 1/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.963 total time=   3.7s
# [CV 2/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.964 total time=   3.7s
# [CV 3/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.964 total time=   3.7s
# [CV 4/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.965 total time=   3.7s
# [CV 5/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.953 total time=   3.7s
# ----------> Model Trained:  rfc
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.931 total time=   2.0s
# [CV 2/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.931 total time=   2.0s
# [CV 3/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.922 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.927 total time=   2.0s
# [CV 5/5] END max_depth=20, min_samples_split=2, n_estimators=100;, score=0.920 total time=   2.0s
# [CV 1/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.931 total time=   3.9s
# [CV 2/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.929 total time=   3.8s
# [CV 3/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.916 total time=   3.9s
# [CV 4/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.925 total time=   3.9s
# [CV 5/5] END max_depth=20, min_samples_split=2, n_estimators=200;, score=0.918 total time=   3.9s
# [CV 1/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.929 total time=   2.0s
# [CV 2/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.928 total time=   2.0s
# [CV 3/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.917 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.927 total time=   2.0s
# [CV 5/5] END max_depth=20, min_samples_split=5, n_estimators=100;, score=0.918 total time=   2.0s
# [CV 1/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.932 total time=   3.9s
# [CV 2/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.925 total time=   3.9s
# [CV 3/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.913 total time=   3.9s
# [CV 4/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.924 total time=   3.9s
# [CV 5/5] END max_depth=20, min_samples_split=5, n_estimators=200;, score=0.918 total time=   4.1s
# [CV 1/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.925 total time=   2.0s
# [CV 2/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.929 total time=   2.1s
# [CV 3/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.914 total time=   2.0s
# [CV 4/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.925 total time=   2.0s
# [CV 5/5] END max_depth=20, min_samples_split=10, n_estimators=100;, score=0.918 total time=   2.0s
# [CV 1/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.932 total time=   4.0s
# [CV 2/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.925 total time=   3.9s
# [CV 3/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.918 total time=   3.9s
# [CV 4/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.928 total time=   3.9s
# [CV 5/5] END max_depth=20, min_samples_split=10, n_estimators=200;, score=0.916 total time=   3.9s
# [CV 1/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.950 total time=   2.8s
# [CV 2/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.947 total time=   2.8s
# [CV 3/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.938 total time=   2.8s
# [CV 4/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.945 total time=   3.0s
# [CV 5/5] END max_depth=30, min_samples_split=2, n_estimators=100;, score=0.939 total time=   2.9s
# [CV 1/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.947 total time=   5.6s
# [CV 2/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.945 total time=   5.5s
# [CV 3/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.938 total time=   5.6s
# [CV 4/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.943 total time=   5.6s
# [CV 5/5] END max_depth=30, min_samples_split=2, n_estimators=200;, score=0.938 total time=   5.6s
# [CV 1/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.946 total time=   2.8s
# [CV 2/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.945 total time=   2.8s
# [CV 3/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.935 total time=   2.8s
# [CV 4/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.949 total time=   2.8s
# [CV 5/5] END max_depth=30, min_samples_split=5, n_estimators=100;, score=0.942 total time=   2.8s
# [CV 1/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.947 total time=   5.5s
# [CV 2/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.946 total time=   5.5s
# [CV 3/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.939 total time=   5.5s
# [CV 4/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.949 total time=   5.5s
# [CV 5/5] END max_depth=30, min_samples_split=5, n_estimators=200;, score=0.939 total time=   5.5s
# [CV 1/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.947 total time=   2.8s
# [CV 2/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.949 total time=   2.8s
# [CV 3/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.940 total time=   2.8s
# [CV 4/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.943 total time=   2.7s
# [CV 5/5] END max_depth=30, min_samples_split=10, n_estimators=100;, score=0.939 total time=   2.8s
# [CV 1/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.947 total time=   5.5s
# [CV 2/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.945 total time=   5.6s
# [CV 3/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.936 total time=   5.6s
# [CV 4/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.947 total time=   5.5s
# [CV 5/5] END max_depth=30, min_samples_split=10, n_estimators=200;, score=0.945 total time=   5.5s
# [CV 1/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.963 total time=   4.3s
# [CV 2/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.965 total time=   4.2s
# [CV 3/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.960 total time=   4.3s
# [CV 4/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.963 total time=   4.2s
# [CV 5/5] END max_depth=50, min_samples_split=2, n_estimators=100;, score=0.953 total time=   4.2s
# [CV 1/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.964 total time=   8.5s
# [CV 2/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.963 total time=   8.4s
# [CV 3/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.964 total time=   8.4s
# [CV 4/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.967 total time=   8.5s
# [CV 5/5] END max_depth=50, min_samples_split=2, n_estimators=200;, score=0.952 total time=   8.6s
# [CV 1/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.963 total time=   4.3s
# [CV 2/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.963 total time=   4.3s
# [CV 3/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.964 total time=   4.3s
# [CV 4/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.964 total time=   4.3s
# [CV 5/5] END max_depth=50, min_samples_split=5, n_estimators=100;, score=0.956 total time=   4.2s
# [CV 1/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.964 total time=   8.5s
# [CV 2/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.965 total time=   8.5s
# [CV 3/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.960 total time=   8.5s
# [CV 4/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.967 total time=   8.5s
# [CV 5/5] END max_depth=50, min_samples_split=5, n_estimators=200;, score=0.953 total time=   8.5s
# [CV 1/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.965 total time=   4.2s
# [CV 2/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.968 total time=   4.2s
# [CV 3/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.964 total time=   4.2s
# [CV 4/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.965 total time=   4.2s
# [CV 5/5] END max_depth=50, min_samples_split=10, n_estimators=100;, score=0.954 total time=   4.2s
# [CV 1/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.964 total time=   8.5s
# [CV 2/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.964 total time=   8.4s
# [CV 3/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.964 total time=   8.5s
# [CV 4/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.968 total time=   8.4s
# [CV 5/5] END max_depth=50, min_samples_split=10, n_estimators=200;, score=0.956 total time=   8.4s
# ----------> Model Trained:  etc
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END metric=euclidean, n_neighbors=2, weights=distance;, score=0.942 total time=   0.3s
# [CV 2/5] END metric=euclidean, n_neighbors=2, weights=distance;, score=0.934 total time=   0.3s
# [CV 3/5] END metric=euclidean, n_neighbors=2, weights=distance;, score=0.921 total time=   0.3s
# [CV 4/5] END metric=euclidean, n_neighbors=2, weights=distance;, score=0.938 total time=   0.3s
# [CV 5/5] END metric=euclidean, n_neighbors=2, weights=distance;, score=0.932 total time=   0.3s
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.932 total time=   0.3s
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.925 total time=   0.4s
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.911 total time=   0.3s
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.931 total time=   0.3s
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.917 total time=   0.3s
# [CV 1/5] END metric=manhattan, n_neighbors=2, weights=distance;, score=0.936 total time=   6.4s
# [CV 2/5] END metric=manhattan, n_neighbors=2, weights=distance;, score=0.932 total time=   6.3s
# [CV 3/5] END metric=manhattan, n_neighbors=2, weights=distance;, score=0.924 total time=   6.3s
# [CV 4/5] END metric=manhattan, n_neighbors=2, weights=distance;, score=0.934 total time=   6.2s
# [CV 5/5] END metric=manhattan, n_neighbors=2, weights=distance;, score=0.929 total time=   6.2s
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.932 total time=   6.4s
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.925 total time=   6.2s
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.914 total time=   6.2s
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.931 total time=   6.2s
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.920 total time=   6.2s
# ----------> Model Trained:  knc

# %%
performance_df.sort_values('Precision', ascending=False)
# Out:
#   Algorithm  Accuracy  Precision  \
# 2       knc  0.947028   1.000000
# 1       etc  0.968992   0.993197
# 0       rfc  0.967054   0.993056
#
#                                               Params
# 2  metric : euclidean, n_neighbors : 2, weights :...
# 1  max_depth : 50, min_samples_split : 10, n_esti...
# 0  max_depth : 50, min_samples_split : 5, n_estim...

# %%
#We Choose ETC Model

# %% [markdown]
# ## Model Performance Report

# %%
from sklearn.metrics import classification_report, confusion_matrix

predictions = models['etc'].predict(X_test)

print("Classification Report:\n", classification_report(y_test, predictions))

conf_matrix = confusion_matrix(y_test, predictions)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1355
#            1       0.99      0.76      0.86       193
#
#     accuracy                           0.97      1548
#    macro avg       0.98      0.88      0.92      1548
# weighted avg       0.97      0.97      0.97      1548
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# ## Saving the Model

# %%
from joblib import dump, load
dump(model, 'spam_prediction.joblib')
# Out:
# ['spam_prediction.joblib']
