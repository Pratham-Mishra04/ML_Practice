# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df['name'] =df['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
df.sample(10)
# Out:
#                        name   company  year     Price  kms_driven fuel_type
# 173         Hyundai Eon Era   Hyundai  2013  1,85,000  27,000 kms    Petrol
# 315              Honda City     Honda  2015  6,44,999  39,000 kms    Petrol
# 76              Honda Amaze     Honda  2015  3,44,999  22,000 kms    Petrol
# 308  Ford EcoSport Titanium      Ford  2014  5,20,000  57,000 kms    Diesel
# 71     Renault Duster 110PS   Renault  2012  5,01,000  35,000 kms    Diesel
# 741        Mahindra Xylo D2  Mahindra  2011  3,90,000  56,000 kms    Diesel
# 823      Maruti Suzuki Ritz    Maruti  2010  1,50,000  38,000 kms    Diesel
# 793        Mahindra Xylo E8  Mahindra  2011  3,65,000  43,000 kms    Diesel
# 305            Honda Accord     Honda  2009  1,75,000  58,559 kms    Petrol
# 72               Honda City     Honda  2015  4,48,999  54,000 kms    Petrol

# %%
df['name'].isna().sum()
# Out:
# 0

# %%
df['company'].isna().sum()
# Out:
# 0

# %%
df=df[df['year'].str.isnumeric()]

# %%
df.loc[:, 'year'] = df['year'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    object
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 46.0+ KB

# %%
df.sample(10)
# Out:
#                        name   company  year      Price    kms_driven fuel_type
# 421       Hyundai Grand i10   Hyundai  2014   3,40,000    35,000 kms    Petrol
# 664       Hyundai i20 Magna   Hyundai  2011   2,40,000    42,000 kms    Petrol
# 11   Maruti Suzuki Stingray    Maruti  2015   3,15,000    30,000 kms    Petrol
# 469       Toyota Corolla H2    Toyota  2003   1,50,000  1,00,000 kms    Petrol
# 366         Mahindra XUV500  Mahindra  2016  11,30,000    72,000 kms    Diesel
# 847      Maruti Suzuki Alto    Maruti  2019   4,25,000     1,625 kms    Petrol
# 857             Hyundai Eon   Hyundai  2018   2,60,000    25,000 kms    Petrol
# 33      Maruti Suzuki Wagon    Maruti  2013   1,05,000    39,000 kms    Petrol
# 680            Tata Zest XE      Tata  2018   4,50,000  1,02,563 kms    Diesel
# 48        Maruti Suzuki SX4    Maruti  2010   2,49,999    36,000 kms    Petrol

# %%
df.loc[:, 'Price']=df['Price'].str.split(' ').str.get(0).str.replace(',','')

# %%
df.sample(10)
# Out:
#                        name   company  year   Price    kms_driven fuel_type
# 878         Mercedes Benz C  Mercedes  2006  500001    15,000 kms    Petrol
# 869     Maruti Suzuki Swift    Maruti  2016  350000  1,46,000 kms    Diesel
# 539     Maruti Suzuki Wagon    Maruti  2003  130000  1,33,000 kms    Petrol
# 542      Maruti Suzuki Alto    Maruti  2010  110000    55,000 kms    Petrol
# 388      Maruti Suzuki Alto    Maruti  2018     Ask    24,000 kms    Petrol
# 106  Ford EcoSport Titanium      Ford  2014  550000    44,000 kms    Diesel
# 52     Mahindra Scorpio S10  Mahindra  2015  250000    48,508 kms    Diesel
# 704     Maruti Suzuki Wagon    Maruti  2008  140000    68,000 kms    Petrol
# 485     Tata Tigor Revotron      Tata  2019  650000       100 kms    Diesel
# 169          Tata Indigo CS      Tata  2011   85000    11,400 kms    Diesel

# %%
df=df[df['Price'].str.isnumeric()]

# %%
df['Price']=df['Price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    object
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 44.8+ KB

# %%
df['kms_driven']=df['kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
df=df[df['kms_driven'].str.isnumeric()]

# %%
df['kms_driven'] = df['kms_driven'].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    object
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.7+ KB

# %%
df['fuel_type'].isna().sum()
# Out:
# 1

# %%
df.dropna(inplace=True)

# %%
df['fuel_type'].isna().sum()
# Out:
# 0

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    428
# Diesel    386
# LPG         2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6               Ford Figo      Ford  2012  175000       41000    Diesel

# %%
df.describe()
# Out:
#               Price     kms_driven
# count  8.160000e+02     816.000000
# mean   4.117176e+05   46275.531863
# std    4.751844e+05   34297.428044
# min    3.000000e+04       0.000000
# 25%    1.750000e+05   27000.000000
# 50%    2.999990e+05   41000.000000
# 75%    4.912500e+05   56818.500000
# max    8.500003e+06  400000.000000

# %%
df['year_old']=df['year'].apply(lambda x:2021-x)

# %%
df.describe()
# Out:
#               Price     kms_driven    year_old
# count  8.160000e+02     816.000000  816.000000
# mean   4.117176e+05   46275.531863    8.555147
# std    4.751844e+05   34297.428044    4.002992
# min    3.000000e+04       0.000000    2.000000
# 25%    1.750000e+05   27000.000000    6.000000
# 50%    2.999990e+05   41000.000000    8.000000
# 75%    4.912500e+05   56818.500000   11.000000
# max    8.500003e+06  400000.000000   26.000000

# %%
df.drop("year", axis=1, inplace=True)

# %%
df=df.rename(columns={"Price":"price"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   price       816 non-null    int64
#  3   kms_driven  816 non-null    int64
#  4   fuel_type   816 non-null    object
#  5   year_old    816 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 44.6+ KB

# %%
df['company'].value_counts()
# Out:
# company
# Maruti        221
# Hyundai       139
# Mahindra       98
# Tata           65
# Honda          60
# Toyota         36
# Chevrolet      34
# Renault        33
# Ford           30
# Volkswagen     19
# Skoda          13
# Audi           11
# Mini            8
# BMW             8
# Datsun          7
# Mitsubishi      6
# Nissan          6
# Mercedes        6
# Fiat            4
# Force           4
# Hindustan       3
# Jaguar          2
# Land            1
# Jeep            1
# Volvo           1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               price     kms_driven    year_old
# count  8.160000e+02     816.000000  816.000000
# mean   4.117176e+05   46275.531863    8.555147
# std    4.751844e+05   34297.428044    4.002992
# min    3.000000e+04       0.000000    2.000000
# 25%    1.750000e+05   27000.000000    6.000000
# 50%    2.999990e+05   41000.000000    8.000000
# 75%    4.912500e+05   56818.500000   11.000000
# max    8.500003e+06  400000.000000   26.000000

# %%
df=df[df['kms_driven']<200000.000000]

# %%
df=df[df['price']<4000000]

# %%
df.describe()
# Out:
#               price     kms_driven    year_old
# count  8.110000e+02     811.000000  811.000000
# mean   4.019625e+05   45272.298397    8.540074
# std    3.816371e+05   30668.740753    3.989716
# min    3.000000e+04       0.000000    2.000000
# 25%    1.750000e+05   27000.000000    6.000000
# 50%    2.999990e+05   41000.000000    8.000000
# 75%    4.900000e+05   56200.000000   11.000000
# max    3.100000e+06  195000.000000   26.000000

# %%
df.head()
# Out:
#                      name   company   price  kms_driven fuel_type  year_old
# 0     Hyundai Santro Xing   Hyundai   80000       45000    Petrol        14
# 1     Mahindra Jeep CL550  Mahindra  425000          40    Diesel        15
# 3       Hyundai Grand i10   Hyundai  325000       28000    Petrol         7
# 4  Ford EcoSport Titanium      Ford  575000       36000    Diesel         7
# 6               Ford Figo      Ford  175000       41000    Diesel         9

# %%
import seaborn as sns

sns.displot(df['price'])

# %%
X = df.drop('price', axis=1)
y = df['price'] #ETR Performs better in this and LR Performs better in log distribution

# %%
sns.heatmap(df.drop(columns=['name', 'company', 'fuel_type']).corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['company_enc'] = le.fit_transform(df['company'])
df['fuel_enc'] = le.fit_transform(df['fuel_type'])

# %%
sns.heatmap(df.drop(columns=['name', 'company', 'fuel_type']).corr(), annot=True)
# Out:
# <Axes: >

# %%
df.drop(columns=['company_enc', 'fuel_enc'], inplace=True)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer

oh_categories = ['name', 'company']
le_categories = ['fuel_type']

ohe = OneHotEncoder(sparse_output=False, drop='first')
ohe.fit(X[oh_categories])

le = LabelEncoder()
X['fuel_type'] = le.fit_transform(X['fuel_type'])

column_trans = ColumnTransformer(
    [('oh', ohe, oh_categories)],
    remainder='passthrough'
)

#Column transformer to avoid writing this Code-
# X_oh = ohe.fit_transform(X[oh_categories])
# X_transformed = pd.concat([pd.DataFrame(X_oh, columns=ohe.get_feature_names_out(oh_categories)), X], axis=1)

# %%
X=column_trans.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

lr = LinearRegression()
etr = ExtraTreesRegressor(n_estimators=50, random_state=101)

# %%
models = {
    'lr' : lr,
    'etr' : etr,
}

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

def train_model(model, model_name, i):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mae = mean_absolute_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)

    return rmse, mae, r2

# %%
rmse_scores = []
mae_scores = []
r2_scores = []
random_state_values = []

for i in range (0,1000):
    print("----------> Random State: ", i)
    for name, model in models.items():
        rmse, mae, r2 = train_model(model, name, i)
        rmse_scores.append(rmse)
        mae_scores.append(mae)
        r2_scores.append(r2)
        random_state_values.append(i)
# Out:
# ----------> Random State:  0
# ----------> Random State:  1
# ----------> Random State:  2
# ----------> Random State:  3
# ----------> Random State:  4
# ----------> Random State:  5
# ----------> Random State:  6
# ----------> Random State:  7
# ----------> Random State:  8
# ----------> Random State:  9
# ----------> Random State:  10
# ----------> Random State:  11
# ----------> Random State:  12
# ----------> Random State:  13
# ----------> Random State:  14
# ----------> Random State:  15
# ----------> Random State:  16
# ----------> Random State:  17
# ----------> Random State:  18
# ----------> Random State:  19
# ----------> Random State:  20
# ----------> Random State:  21
# ----------> Random State:  22
# ----------> Random State:  23
# ----------> Random State:  24
# ----------> Random State:  25
# ----------> Random State:  26
# ----------> Random State:  27
# ----------> Random State:  28
# ----------> Random State:  29
# ----------> Random State:  30
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':list(models.keys()) * 1000, 'MAE':mae_scores, 'RMSE':rmse_scores, 'R2':r2_scores, "Random State":random_state_values})
performance_df.sort_values('R2', ascending=False, )
# Out:
#      Algorithm           MAE          RMSE            R2  Random State
# 875        etr  6.410903e+04  1.147668e+05  9.056633e-01           437
# 1797       etr  6.405069e+04  1.138809e+05  8.783429e-01           898
# 1933       etr  6.245786e+04  1.111990e+05  8.734571e-01           966
# 1677       etr  5.882038e+04  1.196207e+05  8.692376e-01           838
# 695        etr  7.856358e+04  1.395997e+05  8.685846e-01           347
# ...        ...           ...           ...           ...           ...
# 202         lr  7.014209e+12  4.699809e+13 -1.878740e+16           101
# 1620        lr  9.819455e+12  5.263992e+13 -2.141647e+16           810
# 282         lr  1.016312e+13  6.524632e+13 -2.409692e+16           141
# 908         lr  9.275783e+12  7.331514e+13 -4.156349e+16           454
# 414         lr  1.609092e+13  1.178198e+14 -1.506427e+17           207
#
# [2000 rows x 5 columns]

# %%
performance_df[performance_df["Random State"]==437]
# Out:
#     Algorithm           MAE          RMSE            R2  Random State
# 874        lr  1.257362e+11  1.419524e+12 -1.443223e+13           437
# 875       etr  6.410903e+04  1.147668e+05  9.056633e-01           437

# %%
model = etr

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=437)

model.fit(X_train, y_train)
predictions = model.predict(X_test)

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print("\nMAE: ", mae)
print("RMSE: ", np.sqrt(mse))
print("\nR^2: ", r2)
# Out:
# MAE:  64109.03100204498
# RMSE:  114766.8022933986
#
# R^2:  0.9056633479933218

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.regplot(x=y_test, y=predictions, scatter_kws={'s': 20, 'alpha': 0.5}, line_kws={'color': 'red'})
plt.title("Actual vs. Predicted Values")
plt.xlabel("Actual Values (Y Test)")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
from joblib import dump, load
dump(model, 'model.joblib') 
dump(column_trans, 'transformer.joblib')
dump(le, 'encoder.joblib')
# Out:
# ['encoder.joblib']
